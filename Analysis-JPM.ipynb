# %% [markdown]
# **Summary**
#
# Environment, Social and Corporate Governance (ESG) refers to the three central factors in measuring the sustainability and societal impact of an investment in a company or business. These criteria help to better determin the future financial performance of companies (return and risk).
#
# This analysis extracts text from a ESG report in PDF format from the internet, performs NLP on these information, summaries the key ESG initiatives with WordClouds, TDIDFs and discovers topics by building a Latent Dirichlet Allocation (LDA) model.
#
# To keep this exercise as simple as possible, only one ESG report is being used. Specifically the JP Morgan 2020 sustainability report. Given that ESG is a broad topic. Different companies focus on different aspects of ESG depending on their business operations and culture. One can potentially ingest more ESG reports from different companies across all sectors and industries to capture relevant ESG topics.
#
# **This serves the surpose of the current MSc Project.**
#
# This study can be extended to more reports issued by the many companies across different sectors and industries. We can expect the number of topics to increase when more ESG reports are included in the study. Once relevant ESG topics are identified, then we can potentially calculate ESG scores by topics for all companies. Then we can assess and see whether such ESG score derived through NLP process correlates with the score given by rating agencies downloaded from yahoo finance.
#
# **Installing the Dependencies**

# %%
pip install PyPDF2

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /root/anaconda3/lib/python3.8/site-packages (4.0.1)
# Requirement already satisfied: numpy>=1.11.3 in /root/anaconda3/lib/python3.8/site-packages (from gensim) (1.20.3)
# Requirement already satisfied: smart-open>=1.8.1 in /root/anaconda3/lib/python3.8/site-packages (from gensim) (5.2.0)
# Requirement already satisfied: scipy>=0.18.1 in /root/anaconda3/lib/python3.8/site-packages (from gensim) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /root/anaconda3/lib/python3.8/site-packages (3.6.2)
# Requirement already satisfied: tqdm in /root/anaconda3/lib/python3.8/site-packages (from nltk) (4.62.0)
# Requirement already satisfied: regex in /root/anaconda3/lib/python3.8/site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: joblib in /root/anaconda3/lib/python3.8/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: click in /root/anaconda3/lib/python3.8/site-packages (from nltk) (7.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in /root/anaconda3/lib/python3.8/site-packages (1.8.1)
# Requirement already satisfied: matplotlib in /root/anaconda3/lib/python3.8/site-packages (from WordCloud) (3.4.2)
# Requirement already satisfied: numpy>=1.6.1 in /root/anaconda3/lib/python3.8/site-packages (from WordCloud) (1.20.3)
# Requirement already satisfied: pillow in /root/anaconda3/lib/python3.8/site-packages (from WordCloud) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/anaconda3/lib/python3.8/site-packages (from matplotlib->WordCloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /root/anaconda3/lib/python3.8/site-packages (from matplotlib->WordCloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/anaconda3/lib/python3.8/site-packages (from matplotlib->WordCloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/anaconda3/lib/python3.8/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: six in /root/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->WordCloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfminer
# Out:
# Requirement already satisfied: pdfminer in /root/anaconda3/lib/python3.8/site-packages (20191125)
# Requirement already satisfied: pycryptodome in /root/anaconda3/lib/python3.8/site-packages (from pdfminer) (3.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /root/anaconda3/lib/python3.8/site-packages (1.19.0)
# Requirement already satisfied: gunicorn in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (20.1.0)
# Requirement already satisfied: sqlalchemy in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.4.22)
# Requirement already satisfied: numpy in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.20.3)
# Requirement already satisfied: cloudpickle in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.6.0)
# Requirement already satisfied: packaging in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (21.0)
# Requirement already satisfied: requests>=2.17.3 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (2.25.1)
# Requirement already satisfied: protobuf>=3.7.0 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (3.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (5.4.1)
# Requirement already satisfied: pytz in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (2021.1)
# Requirement already satisfied: alembic<=1.4.1 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.4.1)
# Requirement already satisfied: sqlparse>=0.3.1 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (0.4.1)
# Requirement already satisfied: pandas in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.3.1)
# Requirement already satisfied: docker>=4.0.0 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (5.0.0)
# Requirement already satisfied: prometheus-flask-exporter in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (0.18.2)
# Requirement already satisfied: gitpython>=2.1.0 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (3.1.18)
# Requirement already satisfied: click>=7.0 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (7.1.2)
# Requirement already satisfied: entrypoints in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (0.3)
# Requirement already satisfied: databricks-cli>=0.8.7 in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (0.15.0)
# Requirement already satisfied: querystring-parser in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: Flask in /root/anaconda3/lib/python3.8/site-packages (from mlflow) (1.1.2)
# Requirement already satisfied: Mako in /root/anaconda3/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (1.1.5)
# Requirement already satisfied: python-dateutil in /root/anaconda3/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (2.8.2)
# Requirement already satisfied: python-editor>=0.3 in /root/anaconda3/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (1.0.4)
# Requirement already satisfied: tabulate>=0.7.7 in /root/anaconda3/lib/python3.8/site-packages (from databricks-cli>=0.8.7->mlflow) (0.8.9)
# Requirement already satisfied: six>=1.10.0 in /root/anaconda3/lib/python3.8/site-packages (from databricks-cli>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /root/anaconda3/lib/python3.8/site-packages (from docker>=4.0.0->mlflow) (1.2.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/anaconda3/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /root/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow) (3.0.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/anaconda3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /root/anaconda3/lib/python3.8/site-packages (from sqlalchemy->mlflow) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /root/anaconda3/lib/python3.8/site-packages (from Flask->mlflow) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /root/anaconda3/lib/python3.8/site-packages (from Flask->mlflow) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /root/anaconda3/lib/python3.8/site-packages (from Flask->mlflow) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /root/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask->mlflow) (1.1.1)
# Requirement already satisfied: setuptools>=3.0 in /root/anaconda3/lib/python3.8/site-packages (from gunicorn->mlflow) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from packaging->mlflow) (2.4.7)
# Requirement already satisfied: prometheus-client in /root/anaconda3/lib/python3.8/site-packages (from prometheus-flask-exporter->mlflow) (0.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /root/anaconda3/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (8.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (1.20.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: jinja2 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (4.62.0)
# Requirement already satisfied: setuptools in /root/anaconda3/lib/python3.8/site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /root/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /root/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /root/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /root/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /root/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyLDAvis==2.1.2
# Out:
# Requirement already satisfied: pyLDAvis==2.1.2 in /root/anaconda3/lib/python3.8/site-packages (2.1.2)
# Requirement already satisfied: numpy>=1.9.2 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (1.20.3)
# Requirement already satisfied: pandas>=0.17.0 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (1.3.1)
# Requirement already satisfied: joblib>=0.8.4 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (1.0.1)
# Requirement already satisfied: pytest in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (6.2.4)
# Requirement already satisfied: jinja2>=2.7.2 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (2.11.3)
# Requirement already satisfied: numexpr in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (2.7.3)
# Requirement already satisfied: funcy in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (1.16)
# Requirement already satisfied: future in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (0.18.2)
# Requirement already satisfied: scipy>=0.18.0 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (1.6.2)
# Requirement already satisfied: wheel>=0.23.0 in /root/anaconda3/lib/python3.8/site-packages (from pyLDAvis==2.1.2) (0.37.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /root/anaconda3/lib/python3.8/site-packages (from jinja2>=2.7.2->pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /root/anaconda3/lib/python3.8/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /root/anaconda3/lib/python3.8/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2021.1)
# Requirement already satisfied: six>=1.5 in /root/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis==2.1.2) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (21.2.0)
# Requirement already satisfied: iniconfig in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: packaging in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (1.10.0)
# Requirement already satisfied: toml in /root/anaconda3/lib/python3.8/site-packages (from pytest->pyLDAvis==2.1.2) (0.10.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from packaging->pytest->pyLDAvis==2.1.2) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Installing Dependencies:**

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline

import pandas as pd
import numpy as np

# pd.options.display.max_columns = 50
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', 50)

plt.rcParams.update({'figure.figsize':(15,6), 'figure.dpi':60})
plt.style.use('fivethirtyeight')

# %%
import sys 
sys.path.append('/home/levente/Desktop/project/levtest1')
from filelist import *

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this

# PDF text extraction
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# Others
import requests
import io
import string
import re
from pprint import pprint
from tqdm.notebook import tqdm
import io

# %% [markdown]
# **Creating the Folders**

# %%
DATA_FOLDER = '/home/levente/Desktop/project/levtest1/data'
PDF_FOLDER = '/home/levente/Desktop/project/levtest1/pdf'
createfolder(DATA_FOLDER)
createfolder(PDF_FOLDER)

# %% [markdown]
# **Loading Language Model**

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

import spacy
spacy.cli.download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm", disable=['ner'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /root/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.3)
# Requirement already satisfied: setuptools in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: jinja2 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /root/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /root/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /root/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /root/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.6)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /root/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /root/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# **Preparing StopWords**

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from sklearn.feature_extraction import text
stop_words = text.ENGLISH_STOP_WORDS.union(stop_words)

# %%
', '.join(stop_words)
# Out:
# "further, thus, wherein, whence, needn't, eight, something, whereby, latterly, myself, off, so, found, himself, y, others, next, take, enough, keep, whenever, herself, might, well, when, you're, there, several, hundred, she, find, ain, also, into, around, detail, here, together, namely, whither, ltd, nine, moreover, should've, see, sometime, theirs, became, of, what, his, nor, interest, ve, much, wouldn't, her, who, thick, mill, doesn, thereafter, us, thru, over, hasnt, therein, whom, being, could, you'd, whereas, my, then, does, besides, you've, thence, did, where, two, as, couldn't, isn't, nowhere, yourselves, every, mustn, side, is, by, with, hadn't, four, our, he, nothing, am, eg, ll, if, sixty, un, couldnt, last, elsewhere, often, those, please, at, hence, than, not, fill, becoming, more, amoungst, on, name, everywhere, beyond, hereby, through, become, against, an, doesn't, before, but, needn, up, don, these, t, ma, somewhere, among, haven't, describe, inc, top, due, nevertheless, thin, cant, have, after, cannot, whatever, must, although, isn, onto, somehow, seems, upon, behind, a, noone, yet, thereby, co, weren, without, few, sometimes, me, neither, many, therefore, why, twelve, whole, o, though, whether, another, empty, mightn, almost, ie, won, would, shouldn, full, toward, show, until, six, done, didn, con, such, shan, s, whereupon, anyway, whose, out, whoever, formerly, less, aren't, made, one, hasn't, very, to, will, hadn, wherever, etc, ours, via, you'll, that'll, their, ever, just, becomes, bill, themselves, front, none, everyone, seemed, hereupon, indeed, from, five, third, yours, former, give, across, had, weren't, along, m, mightn't, three, how, seem, hereafter, wasn, mostly, too, meanwhile, d, system, are, again, we, all, do, otherwise, anyhow, else, between, perhaps, either, fifty, some, was, once, were, rather, beforehand, amongst, in, even, already, afterwards, cry, below, however, didn't, hasn, him, per, get, yourself, someone, couldn, latter, under, any, serious, never, each, down, mustn't, back, throughout, and, fifteen, go, can, still, call, aren, ten, since, twenty, put, or, most, it's, about, bottom, seeming, above, now, the, least, nobody, haven, both, no, mine, herein, first, you, other, may, doing, shouldn't, its, thereupon, eleven, move, itself, having, wasn't, anything, they, own, fire, because, de, part, beside, should, for, ourselves, has, amount, alone, that, only, sincere, whereafter, she's, shan't, won't, re, been, anyone, it, during, don't, while, towards, within, everything, this, be, same, your, anywhere, forty, them, which, hers, i, always, wouldn, except"

# %% [markdown]
# **Report Details** This Report is in PDF format and downloadable from a URL.
#
# 1.  Company Name
# 2.  Company Ticker Symbol (obtained from the NYSE website)
# 3.  Year of the Report
# 4.  URL of the Report

# %%
report_company = 'JPMorgan Chase & Co'
report_ticker = 'JPM'
report_year = '2020'
report_url = 'https://www.jpmorganchase.com/content/dam/jpmc/jpmorgan-chase-and-co/documents/jpmc-esg-report-2020.pdf'

# %% [markdown]
# Additional information - ESG Score from Yahoo Finance.
# Extracting using Yfinance a python package.

# %%
import yfinance as yf
import pandas as pd

ticker_info = yf.Ticker(report_ticker)
esg_data = pd.DataFrame(ticker_info.sustainability)
esg_data.columns = [str(ticker_info.ticker)]

esg_data.loc[['totalEsg','socialScore','governanceScore','environmentScore',
              'esgPerformance','percentile','peerGroup','highestControversy'],:]
# Out:
#                          JPM
# 2021-5
# totalEsg               27.98
# socialScore            16.09
# governanceScore        10.79
# environmentScore        1.11
# esgPerformance      AVG_PERF
# percentile             50.37
# peerGroup              Banks
# highestControversy         3

# %% [markdown]
# **Text Extraction**
#
# Extract information from the PDF report.

# %%
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io

# %%
from Crypto.Cipher import AES

# %%
def extract_pdf(file, verbose=False):
    
    if verbose:
        print('Processing {}'.format(file))

    try:
        resource_manager = PDFResourceManager()
        fake_file_handle = io.StringIO()
        codec = 'utf-8'
        laparams = LAParams()

        converter = TextConverter(resource_manager, fake_file_handle, codec=codec, laparams=laparams)
        page_interpreter = PDFPageInterpreter(resource_manager, converter)
        
        password = ""
        maxpages = 0
        caching = True
        pagenos = set()

        content = []

        for page in PDFPage.get_pages(file,
                                      pagenos, 
                                      maxpages=maxpages,
                                      password=password,
                                      caching=True,
                                      check_extractable=False):

            page_interpreter.process_page(page)

            content.append(fake_file_handle.getvalue())

            fake_file_handle.truncate(0)
            fake_file_handle.seek(0)        

        text = '##PAGE_BREAK##'.join(content)

        # close open handles
        converter.close()
        fake_file_handle.close()
        
        return text

    except Exception as e:
        print(e)

        # close open handles
        converter.close()
        fake_file_handle.close()

        return ""

# %%
def extract_content(url):
    """
    A simple user define function that, given a url, download PDF text content
    Parse PDF and return plain text version
    """
    headers={"User-Agent":"Mozilla/5.0"}

    try:
        # retrieve PDF binary stream
        r = requests.get(url, allow_redirects=True, headers=headers)
        
        # access pdf content
        text = extract_pdf(io.BytesIO(r.content))

        # return concatenated content
        return text

    except:
        return ""

# %%
report_content = extract_content(report_url)

# %% [markdown]
# Saving to a json file.

# %%
import json

# %%
report = {'company':report_company, 'year':report_year, 'ticker':report_ticker, 
          'url':report_url, 'content':report_content}

with open(DATA_FOLDER + report_company+report_year+'.json', "w") as outfile:  
    json.dump(report, outfile)

# %% [markdown]
# To re-load json if required

# %%
with open(DATA_FOLDER + 'JPMorgan Chase & Co2020.json') as inputfile:
     report = json.load(inputfile)

# %% [markdown]
# **Natural Language Processing**
#
# **Extracting content by pages and sentences**
#
# 1. Only properly structured sentences are extracted. Sentences that start with a Capital Letter and ends with a period. Sentences that are less than 10 words or more than 50 words are ignored.
# 2. Pages with less than 500 words are excluded from extraction. Would like to focus on pages with mostly text content. This should exclude pages like cover and last page. It should also exclude pages that are more graphical with short notes and comments.

# %%
def remove_non_ascii(text):
    printable = set(string.printable)
    return ''.join(filter(lambda x: x in printable, text))

def not_header(line):
    # as we're consolidating broken lines into paragraphs, we want to make sure not to include headers
    return not line.isupper()

def extract_sentences(nlp, text):
    """
    Extracting ESG statements from raw text by removing junk, URLs, etc.
    We group consecutive lines into paragraphs and use spacy to parse sentences.
    """
    MIN_WORDS_PER_PAGE = 500
    
    pages = text.split('##PAGE_BREAK##')
#     print('Number of Pages: {}'.format(len(pages)))

    lines = []
    for page in pages:
        
        # remove non ASCII characters
        text = remove_non_ascii(page)
        
        if len(text.split(' ')) < MIN_WORDS_PER_PAGE:
#             print('Skipped Page: {}'.format(len(text.split(' '))))
            continue
        
        prev = ""
        for line in text.split('\n\n'):
            # aggregate consecutive lines where text may be broken down
            # only if next line starts with a space or previous does not end with dot.
            if(line.startswith(' ') or not prev.endswith('.')):
                prev = prev + ' ' + line
            else:
                # new paragraph
                lines.append(prev)
                prev = line

        # don't forget left-over paragraph
        lines.append(prev)
        lines.append('##SAME_PAGE##')
        
    lines = '  '.join(lines).split('##SAME_PAGE##')
    
    # clean paragraphs from extra space, unwanted characters, urls, etc.
    # best effort clean up, consider a more versatile cleaner
    
    sentences = []
    pages_content = []

    for line in lines[:-1]:
        # removing header number
        line = re.sub(r'^\s?\d+(.*)$', r'\1', line)
        # removing trailing spaces
        line = line.strip()
        # words may be split between lines, ensure we link them back together
        line = re.sub(r'\s?-\s?', '-', line)
        # remove space prior to punctuation
        line = re.sub(r'\s?([,:;\.])', r'\1', line)
        # ESG contains a lot of figures that are not relevant to grammatical structure
        line = re.sub(r'\d{5,}', r' ', line)
        # remove emails
        line = re.sub(r'\S*@\S*\s?', '', line)
        # remove mentions of URLs
        line = re.sub(r'((http|https)\:\/\/)?[a-zA-Z0-9\.\/\?\:@\-_=#]+\.([a-zA-Z]){2,6}([a-zA-Z0-9\.\&\/\?\:@\-_=#])*', r' ', line)
        # remove multiple spaces
        line = re.sub(r'\s+', ' ', line)
        # join next line with space
        line = re.sub(r' \n', ' ', line)
        line = re.sub(r'.\n', '. ', line)
        line = re.sub(r'\x0c', ' ', line)
        
        pages_content.append(str(line).strip())

        # split paragraphs into well defined sentences using spacy
        for part in list(nlp(line).sents):
            sentences.append(str(part).strip())

#           sentences += nltk.sent_tokenize(line)
            
    # Only interested in full sentences and sentences with 10 to 100 words.
    sentences = [s for s in sentences if re.match('^[A-Z][^?!.]*[?.!]$', s) is not None]
    sentences = [s.replace('\n', ' ') for s in sentences]
    sentences = [s for s in sentences if (len(s.split(' ')) > 10) & (len(s.split(' ')) < 100)]

    return pages_content, sentences

# %%
report_pages, report_sentences = extract_sentences(nlp, report['content'])

# %% [markdown]
# We can remove headers

# %%
headers = ['2020  Environmental,  Social  &  Governance  Report']

for header in headers:
    report_pages = [p.replace(header, "").strip() for p in report_pages]
    report_sentences = [p.replace(header, "").strip() for p in report_sentences]

# %% [markdown]
# Tokenization, Bigrams and Lemmatization

# %%
def run_NLP(content):

    def sent_to_words(sentences):
        for sentence in sentences:
            yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

    # Define functions for stopwords, bigrams, trigrams and lemmatization
    def remove_stopwords(texts):
        return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

    def make_bigrams(texts):
        return [bigram_mod[doc] for doc in texts]

    def make_trigrams(texts):
        return [trigram_mod[bigram_mod[doc]] for doc in texts]

    def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
        """https://spacy.io/api/annotation"""
        texts_out = []
        for sent in texts:
            doc = nlp(" ".join(sent)) 
            texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        return texts_out

    data_words = list(sent_to_words(content))

    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)

    # Remove Stop Words
    data_words_nostops = remove_stopwords(data_words)

    # Form Bigrams
    data_words_bigrams = make_bigrams(data_words_nostops)

    # Do lemmatization keeping only noun, adj, vb, adv
    data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    
    return data_lemmatized

# %% [markdown]
# Using full text content in a page rather than full text content in a sentence here. A page defined as a document as per TFIDF calculation.

# %%
data_lemmatized = run_NLP(report_pages)

# %%
report_sentences_lemma = [' '.join(w) for w in data_lemmatized]

# %%
import random
report_sentences_lemma[random.randint(0, len(report_sentences_lemma))]
# Out:
# 'customer service global financial institution lose sight main mission serve customer client line business serve million consumer small_businesses corporation local national government investor range institution world know earn trust customer achieve goal continue enable company stand test time section principally approach customer service ccb business serve consumer small_businesse chase brand page help customer member community serve strengthen financial health page provide resource support small_businesse entrepreneur treat customer fairly build deep last customer relationship require treat customer fairly communicate transparently deliver product service inclusive way respect reflect diversity customer serve strive cultivate customer focus culture employee encourage reward right customer develop internal policy procedure aim simplify disclosure communication align sale practice customer interest protect customer financial abuse discrimination addition take range step ensure commitment diversity equity inclusion firmly embed design deliver product service customer act good customer objective provide customer right product service meet financial need train assess reward employee accordingly advice employee provide consistent customer goal appropriate situation transaction employee aim meet individualized need client customer year educate banker customer center policy procedure control maintain performance metric tie requirement use evaluate banker performance robust governance oversight adherence policy procedure oversight sale practice include sale relate incentive compensation plan perform line business culture conduct committee appropriate forum line business review approve annually incentive plan relate customer face sale activity impact direct sale activity identify mitigate potential conflict risk present regularly review various aspect sale practice include sale culture incentive plan control assessment feedback receive customer employee multiple channel include employee conduct hotline take feedback account help mitigate risk safeguard reputation align employee performance good interest customer put diversity equity inclusion center serve customer believe term growth success firm depend diverse workforce reflect customer serve develop deliver product service way inclusive equitable respectful customer take range step recent year review policy procedure program help ensure fair employee customer result improve tool manager use monitor employee decision customer eligibility certain product benefit help ensure fair access simplify process manage customer complaint flag concern direct senior management review continually look way product service accessible customer example open branch customer deaf hard hearing locate gallaudet university world prominent university student deaf hard hear major center american sign language asl community new branch design visual branch asl community provide access accommodation deaf community employee deaf environmental_social governance'

# %% [markdown]
# Relevant sentences are now well defined for ESG corpus.
#
# Word Cloud - Corpus Wide Term Frequencies

# %%
# context specific keywords not to include in topic modelling
esg_stop_words = [
  'plc', 'group', 'target',
  'track', 'capital', 'holding',
  'report', 'annualreport',
  'esg', 'bank', 'report',
  'annualreport', 'long', 'make'
]

esg_stop_words.append('report_company')
esg_stop_words.append('JPMorgan Chase & Co')

# our list contains all english stop words + companies names + specific keywords
stop_words = stop_words.union(esg_stop_words)

# %%
from wordcloud import WordCloud

# aggregate all 7200 records into one large string to run wordcloud on term frequency
large_string = ' '.join(report_sentences_lemma)

# use 3rd party lib to compute term freq., apply stop words
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=1500, 
    height=1000, 
    stopwords=stop_words, 
    contour_width=3, 
    contour_color='steelblue'
)

# display our wordcloud across all records
plt.figure(figsize=(16,16))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **TFIDF - Unigram and Bigram Analysis**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# Run bi-gram TF-IDF frequencies
bigram_tf_idf_vectorizer = TfidfVectorizer(stop_words=stop_words, ngram_range=(1,2), min_df=10, use_idf=True)
bigram_tf_idf = bigram_tf_idf_vectorizer.fit_transform(report_sentences_lemma)

# Extract bi-grams names
words = bigram_tf_idf_vectorizer.get_feature_names()

# extract our top 10 ngrams
total_counts = np.zeros(len(words))
for t in bigram_tf_idf:
    total_counts += t.toarray()[0]

count_dict = (zip(words, total_counts))
count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:30]
words = [w[0] for w in count_dict]
counts = [w[1] for w in count_dict]
x_pos = np.arange(len(words)) 

# Plot top 10 ngrams
plt.figure(figsize=(16, 6))
plt.subplot(title='30 most common uni-gram and bi-grams')
sns.barplot(x_pos, counts, palette='Blues_r')
plt.xticks(x_pos, words, rotation=90) 
plt.xlabel('N-grams')
plt.ylabel('tfidf')
plt.show()

# %% [markdown]
# **Topic Modeling and Latent Dirichlet Allocation (LDA)**
#
# **Evaluaton Metrics**
#
# **Perplexity: Captures how surprised a model is of new data it has not seen before, and is measured as the normalized log-likelihood of a held-out test set. Lower the better. Coherence Score: Measures score a single topic by measuring the degree of semantic similarity between high scoring words in the topic. Higher the better. In the analysis, the model with the highest coherence score is selected as the optimal model.**

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
results = []
optimal_score = 0
optimal_model = None

for num_of_topics in tqdm(range(2,15,1)):
    
    result = {}
    
    # Build LDA model
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                id2word=id2word,
                                                num_topics=num_of_topics, 
                                                random_state=42,
                                                update_every=1,
                                                chunksize=5,
                                                passes=20,
                                                alpha='auto',
                                                per_word_topics=True) 

    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    
    if optimal_score < coherence_model_lda.get_coherence():
        optimal_score = coherence_model_lda.get_coherence()
        optimal_model = lda_model

    result['num_of_topics'] = num_of_topics
    result['perplexity'] = lda_model.log_perplexity(corpus)
    result['coherence_score'] = coherence_model_lda.get_coherence()
    
    results.append(result)
    
results = pd.DataFrame(results)  
results.set_index('num_of_topics', inplace=True)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
results.plot(secondary_y='perplexity')
plt.show()

# %%
results
# Out:
#                perplexity  coherence_score
# num_of_topics
# 2               -6.893532         0.406507
# 3               -6.862960         0.451106
# 4               -6.947872         0.359737
# 5               -6.950799         0.399797
# 6               -6.970517         0.456660
# 7               -6.997346         0.413758
# 8               -6.991479         0.367669
# 9               -6.999021         0.328019
# 10              -6.996406         0.274994
# 11              -7.000162         0.218106
# 12              -7.317658         0.233251
# 13              -7.925698         0.233256
# 14              -8.727044         0.258092

# %%
# Compute Perplexity
print('\nPerplexity of the Optimal Model: ', optimal_model.log_perplexity(corpus))  

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=optimal_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score of the Optimal Model: ', coherence_lda)
# Out:
# Perplexity of the Optimal Model:  -6.970516540955441
#
# Coherence Score of the Optimal Model:  0.4566597621414454

# %% [markdown]
# **Visualize the topics**

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.106501  0.163620       1        1  33.017504
# 1     -0.198167 -0.094856       2        1  17.977798
# 3      0.097945  0.183407       3        1  17.876252
# 2      0.187676 -0.139466       4        1  11.379474
# 0     -0.070787 -0.105614       5        1  10.409457
# 5      0.089833 -0.007091       6        1   9.339516, topic_info=          Term        Freq       Total Category  logprob  loglift
# 141       risk  108.000000  108.000000  Default  30.0000  30.0000
# 202   employee   75.000000   75.000000  Default  29.0000  29.0000
# 41    customer   78.000000   78.000000  Default  28.0000  28.0000
# 347    climate   60.000000   60.000000  Default  27.0000  27.0000
# 52   financial  104.000000  104.000000  Default  26.0000  26.0000
# ..         ...         ...         ...      ...      ...      ...
# 53        firm   12.601653  100.496527   Topic6  -4.4660   0.2946
# 52   financial   11.961407  104.506582   Topic6  -4.5182   0.2034
# 337   approach    7.120972   30.928427   Topic6  -5.0368   0.9023
# 300      share    5.575295   17.424179   Topic6  -5.2815   1.2314
# 17    business    5.670028  124.042279   Topic6  -5.2646  -0.7145
#
# [352 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 933       1  0.960730    access
# 1208      2  0.873787   account
# 1208      5  0.134429   account
# 710       6  0.890866     acute
# 165       1  0.400295  addition
# ...     ...       ...       ...
# 161       4  0.314036     world
# 161       5  0.314036     world
# 164       1  0.756311      year
# 164       4  0.132355      year
# 164       5  0.113447      year
#
# [478 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 2, 4, 3, 1, 6])

# %%
# Print the Keyword in the 10 topics
pprint(optimal_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.043*"employee" + 0.017*"policy" + 0.013*"pay" + 0.011*"program" + '
#   '0.010*"education" + 0.010*"work" + 0.010*"require" + 0.009*"emerge" + '
#   '0.008*"need" + 0.008*"travel"'),
#  (1,
#   '0.036*"customer" + 0.033*"financial" + 0.014*"community" + 0.014*"asset" + '
#   '0.012*"household" + 0.012*"investment" + 0.011*"service" + 0.011*"banking" '
#   '+ 0.011*"housing" + 0.010*"provide"'),
#  (2,
#   '0.025*"energy" + 0.023*"sector" + 0.022*"emission" + 0.022*"portfolio" + '
#   '0.018*"company" + 0.017*"transition" + 0.015*"carbon" + 0.012*"need" + '
#   '0.011*"challenge" + 0.010*"paris_agreement"'),
#  (3,
#   '0.024*"client" + 0.023*"management" + 0.022*"business" + 0.018*"finance" + '
#   '0.015*"strategy" + 0.014*"sustainable" + 0.013*"risk" + '
#   '0.013*"sustainability" + 0.011*"green" + 0.011*"environmental_social"'),
#  (4,
#   '0.022*"support" + 0.018*"community" + 0.015*"help" + 0.015*"firm" + '
#   '0.014*"development" + 0.014*"business" + 0.013*"new" + 0.012*"program" + '
#   '0.011*"advance" + 0.011*"low"'),
#  (5,
#   '0.073*"risk" + 0.037*"climate" + 0.020*"impact" + 0.014*"climate_change" + '
#   '0.011*"firm" + 0.011*"financial" + 0.010*"transition" + 0.010*"policy" + '
#   '0.010*"relate" + 0.010*"physical"')]

# %% [markdown]
# **Distinguishing the different ESG topics**

# %%
topic_names = {0: 'sustainable finance', 1: 'ethical investments'}

#     'value employees',
#     'ethical investments',
#     'strong governance',
#     'focus customer',    
#     'green energy',
#     'support community',
#     'code of conduct',
#     'sustainable finance',
#     'company transformation',

# %%
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=50,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = optimal_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, 2, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title(topic_names[i], fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
